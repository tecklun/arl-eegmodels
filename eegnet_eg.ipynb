# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.3.0'

# %%
"""
 Sample script using EEGNet to classify Event-Related Potential (ERP) EEG data
 from a four-class classification task, using the sample dataset provided in
 the MNE [1, 2] package:
     https://martinos.org/mne/stable/manual/sample_dataset.html#ch-sample-data
   
 The four classes used from this dataset are:
     LA: Left-ear auditory stimulation
     RA: Right-ear auditory stimulation
     LV: Left visual field stimulation
     RV: Right visual field stimulation

 The code to process, filter and epoch the data are originally from Alexandre
 Barachant's PyRiemann [3] package, released under the BSD 3-clause. A copy of 
 the BSD 3-clause license has been provided together with this software to 
 comply with software licensing requirements. 
 
 When you first run this script, MNE will download the dataset and prompt you
 to confirm the download location (defaults to ~/mne_data). Follow the prompts
 to continue. The dataset size is approx. 1.5GB download. 
 
 For comparative purposes you can also compare EEGNet performance to using 
 Riemannian geometric approaches with xDAWN spatial filtering [4-8] using 
 PyRiemann (code provided below).

 [1] A. Gramfort, M. Luessi, E. Larson, D. Engemann, D. Strohmeier, C. Brodbeck,
     L. Parkkonen, M. Hämäläinen, MNE software for processing MEG and EEG data, 
     NeuroImage, Volume 86, 1 February 2014, Pages 446-460, ISSN 1053-8119.

 [2] A. Gramfort, M. Luessi, E. Larson, D. Engemann, D. Strohmeier, C. Brodbeck, 
     R. Goj, M. Jas, T. Brooks, L. Parkkonen, M. Hämäläinen, MEG and EEG data 
     analysis with MNE-Python, Frontiers in Neuroscience, Volume 7, 2013.

 [3] https://github.com/alexandrebarachant/pyRiemann. 

 [4] A. Barachant, M. Congedo ,"A Plug&Play P300 BCI Using Information Geometry"
     arXiv:1409.0107. link

 [5] M. Congedo, A. Barachant, A. Andreev ,"A New generation of Brain-Computer 
     Interface Based on Riemannian Geometry", arXiv: 1310.8115.

 [6] A. Barachant and S. Bonnet, "Channel selection procedure using riemannian 
     distance for BCI applications," in 2011 5th International IEEE/EMBS 
     Conference on Neural Engineering (NER), 2011, 348-351.

 [7] A. Barachant, S. Bonnet, M. Congedo and C. Jutten, “Multiclass 
     Brain-Computer Interface Classification by Riemannian Geometry,” in IEEE 
     Transactions on Biomedical Engineering, vol. 59, no. 4, p. 920-928, 2012.

 [8] A. Barachant, S. Bonnet, M. Congedo and C. Jutten, “Classification of 
     covariance matrices using a Riemannian-based kernel for BCI applications“, 
     in NeuroComputing, vol. 112, p. 172-178, 2013.


 Portions of this project are works of the United States Government and are not
 subject to domestic copyright protection under 17 USC Sec. 105.  Those 
 portions are released world-wide under the terms of the Creative Commons Zero 
 1.0 (CC0) license.  
 
 Other portions of this project are subject to domestic copyright protection 
 under 17 USC Sec. 105.  Those portions are licensed under the Apache 2.0 
 license.  The complete text of the license governing this material is in 
 the file labeled LICENSE.TXT that is a part of this project's official 
 distribution. 
"""

import numpy as np

# mne imports
import mne
from mne import io
from mne.datasets import sample

# EEGNet-specific imports
from EEGModels import EEGNet
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint

# PyRiemann imports
# from pyriemann.estimation import XdawnCovariances
# from pyriemann.tangentspace import TangentSpace
# from pyriemann.utils.viz import plot_confusion_matrix
# from sklearn.pipeline import make_pipeline
# from sklearn.linear_model import LogisticRegression

# tools for plotting confusion matrices
from matplotlib import pyplot as plt

# %%
##################### Process, filter and epoch the data ######################
data_path = sample.data_path()

# Set parameters and read data
raw_fname = data_path + '/MEG/sample/sample_audvis_filt-0-40_raw.fif'
event_fname = data_path + '/MEG/sample/sample_audvis_filt-0-40_raw-eve.fif'
tmin, tmax = -0., 1
event_id = dict(aud_l=1, aud_r=2, vis_l=3, vis_r=4)

# %%
# Setup for reading the raw data
raw = io.Raw(raw_fname, preload=True, verbose=False)
raw.filter(2, None, method='iir')  # replace baselining with high-pass
events = mne.read_events(event_fname)

raw.info['bads'] = ['MEG 2443']  # set bad channels
picks = mne.pick_types(raw.info, meg=False, eeg=True, stim=False, eog=False,
                       exclude='bads')

# Read epochs
epochs = mne.Epochs(raw, events, event_id, tmin, tmax, proj=False,
                    picks=picks, baseline=None, preload=True, verbose=False)
labels = epochs.events[:, -1]

# extract raw data. scale by 1000 due to scaling sensitivity in deep learning
X = epochs.get_data()*1000 # format is in (trials, channels, samples)
y = labels

kernels, chans, samples = 1, 60, 151

# take 50/25/25 percent of the data to train/validate/test
X_train      = X[0:144,]
Y_train      = y[0:144]
X_validate   = X[144:216,]
Y_validate   = y[144:216]
X_test       = X[216:,]
Y_test       = y[216:]

# %%
############################# EEGNet portion ##################################

# convert labels to one-hot encodings.
Y_train      = np_utils.to_categorical(Y_train-1)
Y_validate   = np_utils.to_categorical(Y_validate-1)
Y_test       = np_utils.to_categorical(Y_test-1)

# convert data to NCHW (trials, kernels, channels, samples) format. Data 
# contains 60 channels and 151 time-points. Set the number of kernels to 1.
X_train      = X_train.reshape(X_train.shape[0], kernels, chans, samples)
X_validate   = X_validate.reshape(X_validate.shape[0], kernels, chans, samples)
X_test       = X_test.reshape(X_test.shape[0], kernels, chans, samples)
   
print('X_train shape:', X_train.shape)
print('Y_test.shape:', Y_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

# configure the EEGNet-8,2,16 model with kernel length of 32 samples (other 
# model configurations may do better, but this is a good starting point)
model = EEGNet(nb_classes = 4, Chans = chans, Samples = samples, 
               dropoutRate = 0.5, kernLength = 32, F1 = 8, D = 2, F2 = 16, 
               dropoutType = 'Dropout')

# compile the model and set the optimizers
model.compile(loss='categorical_crossentropy', optimizer='adam', 
              metrics = ['accuracy'])

# count number of parameters in the model
numParams    = model.count_params()    

# set a valid path for your system to record model checkpoints
checkpointer = ModelCheckpoint(filepath='/tmp/checkpoint.h5', verbose=1,
                               save_best_only=True)

###############################################################################
# if the classification task was imbalanced (significantly more trials in one
# class versus the others) you can assign a weight to each class during 
# optimization to balance it out. This data is approximately balanced so we 
# don't need to do this, but is shown here for illustration/completeness. 
###############################################################################

# the syntax is {class_1:weight_1, class_2:weight_2,...}. Here just setting
# the weights all to be 1
class_weights = {0:1, 1:1, 2:1, 3:1}

################################################################################
# fit the model. Due to very small sample sizes this can get
# pretty noisy run-to-run, but most runs should be comparable to xDAWN + 
# Riemannian geometry classification (below)
################################################################################
fittedModel = model.fit(X_train, Y_train, batch_size = 16, epochs = 300, 
                        verbose = 2, validation_data=(X_validate, Y_validate),
                        callbacks=[checkpointer], class_weight = class_weights)

# load optimal weights
model.load_weights('/tmp/checkpoint.h5')

###############################################################################
# can alternatively used the weights provided in the repo. If so it should get
# you 93% accuracy. Change the WEIGHTS_PATH variable to wherever it is on your
# system.
###############################################################################

# WEIGHTS_PATH = /path/to/EEGNet-8-2-weights.h5 
# model.load_weights(WEIGHTS_PATH)

###############################################################################
# make prediction on test set.
###############################################################################

probs       = model.predict(X_test)
preds       = probs.argmax(axis = -1)  
acc         = np.mean(preds == Y_test.argmax(axis=-1))
print("Classification accuracy: %f " % (acc))


############################# PyRiemann Portion ##############################

# code is taken from PyRiemann's ERP sample script, which is decoding in 
# the tangent space with a logistic regression

n_components = 2  # pick some components

# set up sklearn pipeline
clf = make_pipeline(XdawnCovariances(n_components),
                    TangentSpace(metric='riemann'),
                    LogisticRegression())

preds_rg     = np.zeros(len(Y_test))

# reshape back to (trials, channels, samples)
X_train      = X_train.reshape(X_train.shape[0], chans, samples)
X_test       = X_test.reshape(X_test.shape[0], chans, samples)

# train a classifier with xDAWN spatial filtering + Riemannian Geometry (RG)
# labels need to be back in single-column format
clf.fit(X_train, Y_train.argmax(axis = -1))
preds_rg     = clf.predict(X_test)

# Printing the results
acc2         = np.mean(preds_rg == Y_test.argmax(axis = -1))
print("Classification accuracy: %f " % (acc2))

# plot the confusion matrices for both classifiers
names        = ['audio left', 'audio right', 'vis left', 'vis right']
plt.figure(0)
plot_confusion_matrix(preds, Y_test.argmax(axis = -1), names, title = 'EEGNet-8,2')

plt.figure(1)
plot_confusion_matrix(preds_rg, Y_test.argmax(axis = -1), names, title = 'xDAWN + RG')
# Out:
# X_train shape: (144, 1, 60, 151)
# Y_test.shape: (144, 4)
# 144 train samples
# 72 test samples
# 60 151 32 8
# (None, 8, 60, 151)
# 60 151 32 8
# (None, 4)
# Epoch 1/300
#
# Epoch 00001: val_loss improved from inf to 1.38643, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 1.4118 - accuracy: 0.1597 - val_loss: 1.3864 - val_accuracy: 0.2361
# Epoch 2/300
#
# Epoch 00002: val_loss did not improve from 1.38643
# 9/9 - 0s - loss: 1.3842 - accuracy: 0.2847 - val_loss: 1.3865 - val_accuracy: 0.2361
# Epoch 3/300
#
# Epoch 00003: val_loss did not improve from 1.38643
# 9/9 - 0s - loss: 1.3787 - accuracy: 0.2986 - val_loss: 1.3865 - val_accuracy: 0.2361
# Epoch 4/300
#
# Epoch 00004: val_loss did not improve from 1.38643
# 9/9 - 0s - loss: 1.3758 - accuracy: 0.2708 - val_loss: 1.3866 - val_accuracy: 0.2361
# Epoch 5/300
#
# Epoch 00005: val_loss did not improve from 1.38643
# 9/9 - 0s - loss: 1.3748 - accuracy: 0.3125 - val_loss: 1.3866 - val_accuracy: 0.2361
# Epoch 6/300
#
# Epoch 00006: val_loss did not improve from 1.38643
# 9/9 - 0s - loss: 1.3801 - accuracy: 0.3194 - val_loss: 1.3866 - val_accuracy: 0.2361
# Epoch 7/300
#
# Epoch 00007: val_loss did not improve from 1.38643
# 9/9 - 0s - loss: 1.3695 - accuracy: 0.3611 - val_loss: 1.3867 - val_accuracy: 0.2361
# Epoch 8/300
#
# Epoch 00008: val_loss did not improve from 1.38643
# 9/9 - 0s - loss: 1.3696 - accuracy: 0.2986 - val_loss: 1.3867 - val_accuracy: 0.2361
# Epoch 9/300
#
# Epoch 00009: val_loss did not improve from 1.38643
# 9/9 - 0s - loss: 1.3795 - accuracy: 0.3333 - val_loss: 1.3868 - val_accuracy: 0.2361
# Epoch 10/300
#
# Epoch 00010: val_loss did not improve from 1.38643
# 9/9 - 0s - loss: 1.3706 - accuracy: 0.3333 - val_loss: 1.3868 - val_accuracy: 0.2361
# Epoch 11/300
#
# Epoch 00011: val_loss did not improve from 1.38643
# 9/9 - 0s - loss: 1.3574 - accuracy: 0.4167 - val_loss: 1.3869 - val_accuracy: 0.2361
# Epoch 12/300
#
# Epoch 00012: val_loss did not improve from 1.38643
# 9/9 - 0s - loss: 1.3527 - accuracy: 0.3681 - val_loss: 1.3869 - val_accuracy: 0.2361
# Epoch 13/300
#
# Epoch 00013: val_loss did not improve from 1.38643
# 9/9 - 0s - loss: 1.3523 - accuracy: 0.4028 - val_loss: 1.3870 - val_accuracy: 0.2361
# Epoch 14/300
#
# Epoch 00014: val_loss did not improve from 1.38643
# 9/9 - 0s - loss: 1.3364 - accuracy: 0.4653 - val_loss: 1.3870 - val_accuracy: 0.2361
# Epoch 15/300
#
# Epoch 00015: val_loss did not improve from 1.38643
# 9/9 - 0s - loss: 1.3437 - accuracy: 0.4028 - val_loss: 1.3870 - val_accuracy: 0.2361
# Epoch 16/300
#
# Epoch 00016: val_loss did not improve from 1.38643
# 9/9 - 0s - loss: 1.3363 - accuracy: 0.4444 - val_loss: 1.3871 - val_accuracy: 0.2361
# Epoch 17/300
#
# Epoch 00017: val_loss did not improve from 1.38643
# 9/9 - 0s - loss: 1.3156 - accuracy: 0.4653 - val_loss: 1.3871 - val_accuracy: 0.2361
# Epoch 18/300
#
# Epoch 00018: val_loss did not improve from 1.38643
# 9/9 - 0s - loss: 1.3240 - accuracy: 0.4444 - val_loss: 1.3870 - val_accuracy: 0.2361
# Epoch 19/300
#
# Epoch 00019: val_loss did not improve from 1.38643
# 9/9 - 0s - loss: 1.3067 - accuracy: 0.4722 - val_loss: 1.3870 - val_accuracy: 0.2361
# Epoch 20/300
#
# Epoch 00020: val_loss did not improve from 1.38643
# 9/9 - 0s - loss: 1.2968 - accuracy: 0.4931 - val_loss: 1.3869 - val_accuracy: 0.2361
# Epoch 21/300
#
# Epoch 00021: val_loss did not improve from 1.38643
# 9/9 - 0s - loss: 1.2617 - accuracy: 0.5764 - val_loss: 1.3868 - val_accuracy: 0.2361
# Epoch 22/300
#
# Epoch 00022: val_loss did not improve from 1.38643
# 9/9 - 0s - loss: 1.2356 - accuracy: 0.6389 - val_loss: 1.3866 - val_accuracy: 0.2361
# Epoch 23/300
#
# Epoch 00023: val_loss improved from 1.38643 to 1.38638, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 1.2396 - accuracy: 0.6042 - val_loss: 1.3864 - val_accuracy: 0.2361
# Epoch 24/300
#
# Epoch 00024: val_loss improved from 1.38638 to 1.38599, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 1.1935 - accuracy: 0.6111 - val_loss: 1.3860 - val_accuracy: 0.2361
# Epoch 25/300
#
# Epoch 00025: val_loss improved from 1.38599 to 1.38556, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 1.1598 - accuracy: 0.5833 - val_loss: 1.3856 - val_accuracy: 0.2361
# Epoch 26/300
#
# Epoch 00026: val_loss improved from 1.38556 to 1.38509, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 1.1399 - accuracy: 0.6736 - val_loss: 1.3851 - val_accuracy: 0.2361
# Epoch 27/300
#
# Epoch 00027: val_loss improved from 1.38509 to 1.38414, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 1.1405 - accuracy: 0.6389 - val_loss: 1.3841 - val_accuracy: 0.2361
# Epoch 28/300
#
# Epoch 00028: val_loss improved from 1.38414 to 1.38317, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 1.1150 - accuracy: 0.6458 - val_loss: 1.3832 - val_accuracy: 0.2361
# Epoch 29/300
#
# Epoch 00029: val_loss improved from 1.38317 to 1.38192, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 1.0918 - accuracy: 0.7014 - val_loss: 1.3819 - val_accuracy: 0.2361
# Epoch 30/300
#
# Epoch 00030: val_loss improved from 1.38192 to 1.38103, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 1.0497 - accuracy: 0.6806 - val_loss: 1.3810 - val_accuracy: 0.2361
# Epoch 31/300
#
# Epoch 00031: val_loss improved from 1.38103 to 1.37841, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 1.0313 - accuracy: 0.7014 - val_loss: 1.3784 - val_accuracy: 0.2500
# Epoch 32/300
#
# Epoch 00032: val_loss improved from 1.37841 to 1.37658, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 1.0075 - accuracy: 0.7153 - val_loss: 1.3766 - val_accuracy: 0.2778
# Epoch 33/300
#
# Epoch 00033: val_loss improved from 1.37658 to 1.37484, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.9979 - accuracy: 0.7708 - val_loss: 1.3748 - val_accuracy: 0.3194
# Epoch 34/300
#
# Epoch 00034: val_loss improved from 1.37484 to 1.37209, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.9544 - accuracy: 0.7708 - val_loss: 1.3721 - val_accuracy: 0.3333
# Epoch 35/300
#
# Epoch 00035: val_loss improved from 1.37209 to 1.36918, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.9596 - accuracy: 0.7708 - val_loss: 1.3692 - val_accuracy: 0.3611
# Epoch 36/300
#
# Epoch 00036: val_loss improved from 1.36918 to 1.36477, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.9530 - accuracy: 0.7847 - val_loss: 1.3648 - val_accuracy: 0.4167
# Epoch 37/300
#
# Epoch 00037: val_loss improved from 1.36477 to 1.36052, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.9244 - accuracy: 0.7500 - val_loss: 1.3605 - val_accuracy: 0.4167
# Epoch 38/300
#
# Epoch 00038: val_loss improved from 1.36052 to 1.35563, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.9386 - accuracy: 0.7361 - val_loss: 1.3556 - val_accuracy: 0.4028
# Epoch 39/300
#
# Epoch 00039: val_loss improved from 1.35563 to 1.35084, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.9159 - accuracy: 0.7778 - val_loss: 1.3508 - val_accuracy: 0.4306
# Epoch 40/300
#
# Epoch 00040: val_loss improved from 1.35084 to 1.34402, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.9258 - accuracy: 0.7222 - val_loss: 1.3440 - val_accuracy: 0.4861
# Epoch 41/300
#
# Epoch 00041: val_loss improved from 1.34402 to 1.33666, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.9262 - accuracy: 0.6736 - val_loss: 1.3367 - val_accuracy: 0.4861
# Epoch 42/300
#
# Epoch 00042: val_loss improved from 1.33666 to 1.32796, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.9080 - accuracy: 0.6736 - val_loss: 1.3280 - val_accuracy: 0.5278
# Epoch 43/300
#
# Epoch 00043: val_loss improved from 1.32796 to 1.32033, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.8796 - accuracy: 0.7153 - val_loss: 1.3203 - val_accuracy: 0.5972
# Epoch 44/300
#
# Epoch 00044: val_loss improved from 1.32033 to 1.31487, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.8662 - accuracy: 0.7569 - val_loss: 1.3149 - val_accuracy: 0.5833
# Epoch 45/300
#
# Epoch 00045: val_loss improved from 1.31487 to 1.30646, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.8667 - accuracy: 0.7153 - val_loss: 1.3065 - val_accuracy: 0.5972
# Epoch 46/300
#
# Epoch 00046: val_loss improved from 1.30646 to 1.29775, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.8468 - accuracy: 0.7639 - val_loss: 1.2978 - val_accuracy: 0.6250
# Epoch 47/300
#
# Epoch 00047: val_loss improved from 1.29775 to 1.28311, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.8385 - accuracy: 0.7153 - val_loss: 1.2831 - val_accuracy: 0.6806
# Epoch 48/300
#
# Epoch 00048: val_loss improved from 1.28311 to 1.27244, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.8630 - accuracy: 0.7569 - val_loss: 1.2724 - val_accuracy: 0.6806
# Epoch 49/300
#
# Epoch 00049: val_loss improved from 1.27244 to 1.26229, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.8105 - accuracy: 0.7778 - val_loss: 1.2623 - val_accuracy: 0.6528
# Epoch 50/300
#
# Epoch 00050: val_loss improved from 1.26229 to 1.25031, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.8067 - accuracy: 0.8056 - val_loss: 1.2503 - val_accuracy: 0.7083
# Epoch 51/300
#
# Epoch 00051: val_loss improved from 1.25031 to 1.23740, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.7937 - accuracy: 0.8056 - val_loss: 1.2374 - val_accuracy: 0.7083
# Epoch 52/300
#
# Epoch 00052: val_loss improved from 1.23740 to 1.22486, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.8088 - accuracy: 0.7639 - val_loss: 1.2249 - val_accuracy: 0.7083
# Epoch 53/300
#
# Epoch 00053: val_loss improved from 1.22486 to 1.20722, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.8120 - accuracy: 0.7708 - val_loss: 1.2072 - val_accuracy: 0.6806
# Epoch 54/300
#
# Epoch 00054: val_loss improved from 1.20722 to 1.18955, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.7964 - accuracy: 0.7917 - val_loss: 1.1896 - val_accuracy: 0.7222
# Epoch 55/300
#
# Epoch 00055: val_loss improved from 1.18955 to 1.17276, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.7718 - accuracy: 0.7500 - val_loss: 1.1728 - val_accuracy: 0.7222
# Epoch 56/300
#
# Epoch 00056: val_loss improved from 1.17276 to 1.16227, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.7881 - accuracy: 0.7639 - val_loss: 1.1623 - val_accuracy: 0.7083
# Epoch 57/300
#
# Epoch 00057: val_loss improved from 1.16227 to 1.15072, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.8053 - accuracy: 0.7500 - val_loss: 1.1507 - val_accuracy: 0.7222
# Epoch 58/300
#
# Epoch 00058: val_loss improved from 1.15072 to 1.13100, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.7708 - accuracy: 0.7639 - val_loss: 1.1310 - val_accuracy: 0.7083
# Epoch 59/300
#
# Epoch 00059: val_loss improved from 1.13100 to 1.11240, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.7869 - accuracy: 0.7986 - val_loss: 1.1124 - val_accuracy: 0.7222
# Epoch 60/300
#
# Epoch 00060: val_loss improved from 1.11240 to 1.09750, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.7456 - accuracy: 0.7917 - val_loss: 1.0975 - val_accuracy: 0.7361
# Epoch 61/300
#
# Epoch 00061: val_loss improved from 1.09750 to 1.08134, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.7474 - accuracy: 0.7847 - val_loss: 1.0813 - val_accuracy: 0.7778
# Epoch 62/300
#
# Epoch 00062: val_loss improved from 1.08134 to 1.07072, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.7486 - accuracy: 0.7639 - val_loss: 1.0707 - val_accuracy: 0.7639
# Epoch 63/300
#
# Epoch 00063: val_loss improved from 1.07072 to 1.05665, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.7537 - accuracy: 0.7639 - val_loss: 1.0566 - val_accuracy: 0.7639
# Epoch 64/300
#
# Epoch 00064: val_loss improved from 1.05665 to 1.03325, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.7501 - accuracy: 0.7500 - val_loss: 1.0332 - val_accuracy: 0.7639
# Epoch 65/300
#
# Epoch 00065: val_loss improved from 1.03325 to 0.99914, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.7249 - accuracy: 0.7986 - val_loss: 0.9991 - val_accuracy: 0.7361
# Epoch 66/300
#
# Epoch 00066: val_loss improved from 0.99914 to 0.98561, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.7316 - accuracy: 0.8056 - val_loss: 0.9856 - val_accuracy: 0.7361
# Epoch 67/300
#
# Epoch 00067: val_loss improved from 0.98561 to 0.97590, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.7526 - accuracy: 0.7361 - val_loss: 0.9759 - val_accuracy: 0.7500
# Epoch 68/300
#
# Epoch 00068: val_loss improved from 0.97590 to 0.97230, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.7270 - accuracy: 0.7917 - val_loss: 0.9723 - val_accuracy: 0.7361
# Epoch 69/300
#
# Epoch 00069: val_loss improved from 0.97230 to 0.96044, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.7195 - accuracy: 0.8125 - val_loss: 0.9604 - val_accuracy: 0.7361
# Epoch 70/300
#
# Epoch 00070: val_loss did not improve from 0.96044
# 9/9 - 0s - loss: 0.6941 - accuracy: 0.7639 - val_loss: 0.9629 - val_accuracy: 0.7083
# Epoch 71/300
#
# Epoch 00071: val_loss improved from 0.96044 to 0.93841, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.7206 - accuracy: 0.8056 - val_loss: 0.9384 - val_accuracy: 0.7222
# Epoch 72/300
#
# Epoch 00072: val_loss improved from 0.93841 to 0.93037, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.7300 - accuracy: 0.7917 - val_loss: 0.9304 - val_accuracy: 0.7083
# Epoch 73/300
#
# Epoch 00073: val_loss improved from 0.93037 to 0.92760, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.7224 - accuracy: 0.7917 - val_loss: 0.9276 - val_accuracy: 0.7083
# Epoch 74/300
#
# Epoch 00074: val_loss improved from 0.92760 to 0.90307, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.7173 - accuracy: 0.7986 - val_loss: 0.9031 - val_accuracy: 0.7500
# Epoch 75/300
#
# Epoch 00075: val_loss improved from 0.90307 to 0.88724, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.7595 - accuracy: 0.7361 - val_loss: 0.8872 - val_accuracy: 0.7361
# Epoch 76/300
#
# Epoch 00076: val_loss did not improve from 0.88724
# 9/9 - 0s - loss: 0.7253 - accuracy: 0.7569 - val_loss: 0.8952 - val_accuracy: 0.7222
# Epoch 77/300
#
# Epoch 00077: val_loss improved from 0.88724 to 0.87998, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.7007 - accuracy: 0.7986 - val_loss: 0.8800 - val_accuracy: 0.7083
# Epoch 78/300
#
# Epoch 00078: val_loss improved from 0.87998 to 0.83950, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.7113 - accuracy: 0.7431 - val_loss: 0.8395 - val_accuracy: 0.7222
# Epoch 79/300
#
# Epoch 00079: val_loss improved from 0.83950 to 0.83216, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.6956 - accuracy: 0.8194 - val_loss: 0.8322 - val_accuracy: 0.7500
# Epoch 80/300
#
# Epoch 00080: val_loss did not improve from 0.83216
# 9/9 - 0s - loss: 0.7113 - accuracy: 0.7917 - val_loss: 0.8408 - val_accuracy: 0.7500
# Epoch 81/300
#
# Epoch 00081: val_loss improved from 0.83216 to 0.83111, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.7095 - accuracy: 0.7986 - val_loss: 0.8311 - val_accuracy: 0.7222
# Epoch 82/300
#
# Epoch 00082: val_loss improved from 0.83111 to 0.82561, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.7012 - accuracy: 0.7639 - val_loss: 0.8256 - val_accuracy: 0.6944
# Epoch 83/300
#
# Epoch 00083: val_loss improved from 0.82561 to 0.81852, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.6888 - accuracy: 0.7778 - val_loss: 0.8185 - val_accuracy: 0.6806
# Epoch 84/300
#
# Epoch 00084: val_loss improved from 0.81852 to 0.79977, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.6850 - accuracy: 0.8194 - val_loss: 0.7998 - val_accuracy: 0.7361
# Epoch 85/300
#
# Epoch 00085: val_loss improved from 0.79977 to 0.78921, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.6656 - accuracy: 0.8333 - val_loss: 0.7892 - val_accuracy: 0.7500
# Epoch 86/300
#
# Epoch 00086: val_loss improved from 0.78921 to 0.78019, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.7031 - accuracy: 0.7847 - val_loss: 0.7802 - val_accuracy: 0.7222
# Epoch 87/300
#
# Epoch 00087: val_loss improved from 0.78019 to 0.76913, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.6691 - accuracy: 0.8194 - val_loss: 0.7691 - val_accuracy: 0.7500
# Epoch 88/300
#
# Epoch 00088: val_loss did not improve from 0.76913
# 9/9 - 0s - loss: 0.6732 - accuracy: 0.8194 - val_loss: 0.7793 - val_accuracy: 0.7222
# Epoch 89/300
#
# Epoch 00089: val_loss improved from 0.76913 to 0.76211, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.6671 - accuracy: 0.8125 - val_loss: 0.7621 - val_accuracy: 0.7500
# Epoch 90/300
#
# Epoch 00090: val_loss improved from 0.76211 to 0.75116, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.6859 - accuracy: 0.7847 - val_loss: 0.7512 - val_accuracy: 0.7500
# Epoch 91/300
#
# Epoch 00091: val_loss did not improve from 0.75116
# 9/9 - 0s - loss: 0.6685 - accuracy: 0.8125 - val_loss: 0.7533 - val_accuracy: 0.7361
# Epoch 92/300
#
# Epoch 00092: val_loss did not improve from 0.75116
# 9/9 - 0s - loss: 0.6903 - accuracy: 0.7986 - val_loss: 0.7649 - val_accuracy: 0.7222
# Epoch 93/300
#
# Epoch 00093: val_loss did not improve from 0.75116
# 9/9 - 0s - loss: 0.6611 - accuracy: 0.7778 - val_loss: 0.7558 - val_accuracy: 0.7361
# Epoch 94/300
#
# Epoch 00094: val_loss did not improve from 0.75116
# 9/9 - 0s - loss: 0.6265 - accuracy: 0.8472 - val_loss: 0.7595 - val_accuracy: 0.7222
# Epoch 95/300
#
# Epoch 00095: val_loss improved from 0.75116 to 0.74264, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.6753 - accuracy: 0.8194 - val_loss: 0.7426 - val_accuracy: 0.7222
# Epoch 96/300
#
# Epoch 00096: val_loss did not improve from 0.74264
# 9/9 - 0s - loss: 0.6489 - accuracy: 0.8542 - val_loss: 0.7575 - val_accuracy: 0.7222
# Epoch 97/300
#
# Epoch 00097: val_loss did not improve from 0.74264
# 9/9 - 0s - loss: 0.6357 - accuracy: 0.8611 - val_loss: 0.7804 - val_accuracy: 0.7083
# Epoch 98/300
#
# Epoch 00098: val_loss did not improve from 0.74264
# 9/9 - 0s - loss: 0.6349 - accuracy: 0.8125 - val_loss: 0.7774 - val_accuracy: 0.6944
# Epoch 99/300
#
# Epoch 00099: val_loss did not improve from 0.74264
# 9/9 - 0s - loss: 0.6213 - accuracy: 0.8403 - val_loss: 0.7544 - val_accuracy: 0.7083
# Epoch 100/300
#
# Epoch 00100: val_loss did not improve from 0.74264
# 9/9 - 0s - loss: 0.6403 - accuracy: 0.8264 - val_loss: 0.7489 - val_accuracy: 0.7222
# Epoch 101/300
#
# Epoch 00101: val_loss improved from 0.74264 to 0.71988, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.6201 - accuracy: 0.7986 - val_loss: 0.7199 - val_accuracy: 0.7222
# Epoch 102/300
#
# Epoch 00102: val_loss improved from 0.71988 to 0.70098, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.6309 - accuracy: 0.8264 - val_loss: 0.7010 - val_accuracy: 0.7222
# Epoch 103/300
#
# Epoch 00103: val_loss did not improve from 0.70098
# 9/9 - 0s - loss: 0.6262 - accuracy: 0.8264 - val_loss: 0.7110 - val_accuracy: 0.7083
# Epoch 104/300
#
# Epoch 00104: val_loss did not improve from 0.70098
# 9/9 - 0s - loss: 0.6087 - accuracy: 0.8542 - val_loss: 0.7351 - val_accuracy: 0.6944
# Epoch 105/300
#
# Epoch 00105: val_loss did not improve from 0.70098
# 9/9 - 0s - loss: 0.6438 - accuracy: 0.7917 - val_loss: 0.7228 - val_accuracy: 0.7083
# Epoch 106/300
#
# Epoch 00106: val_loss did not improve from 0.70098
# 9/9 - 0s - loss: 0.6193 - accuracy: 0.8403 - val_loss: 0.7132 - val_accuracy: 0.7361
# Epoch 107/300
#
# Epoch 00107: val_loss did not improve from 0.70098
# 9/9 - 0s - loss: 0.5781 - accuracy: 0.8472 - val_loss: 0.7125 - val_accuracy: 0.7222
# Epoch 108/300
#
# Epoch 00108: val_loss did not improve from 0.70098
# 9/9 - 0s - loss: 0.5919 - accuracy: 0.8056 - val_loss: 0.7144 - val_accuracy: 0.7083
# Epoch 109/300
#
# Epoch 00109: val_loss improved from 0.70098 to 0.69591, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.6109 - accuracy: 0.8333 - val_loss: 0.6959 - val_accuracy: 0.7222
# Epoch 110/300
#
# Epoch 00110: val_loss improved from 0.69591 to 0.69382, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.6268 - accuracy: 0.8264 - val_loss: 0.6938 - val_accuracy: 0.7361
# Epoch 111/300
#
# Epoch 00111: val_loss did not improve from 0.69382
# 9/9 - 0s - loss: 0.6027 - accuracy: 0.8333 - val_loss: 0.7138 - val_accuracy: 0.7222
# Epoch 112/300
#
# Epoch 00112: val_loss improved from 0.69382 to 0.69250, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.5709 - accuracy: 0.8611 - val_loss: 0.6925 - val_accuracy: 0.7222
# Epoch 113/300
#
# Epoch 00113: val_loss did not improve from 0.69250
# 9/9 - 0s - loss: 0.5969 - accuracy: 0.8750 - val_loss: 0.6966 - val_accuracy: 0.7222
# Epoch 114/300
#
# Epoch 00114: val_loss did not improve from 0.69250
# 9/9 - 0s - loss: 0.5850 - accuracy: 0.8472 - val_loss: 0.7068 - val_accuracy: 0.7361
# Epoch 115/300
#
# Epoch 00115: val_loss did not improve from 0.69250
# 9/9 - 0s - loss: 0.5985 - accuracy: 0.8333 - val_loss: 0.7174 - val_accuracy: 0.7500
# Epoch 116/300
#
# Epoch 00116: val_loss did not improve from 0.69250
# 9/9 - 0s - loss: 0.5906 - accuracy: 0.8542 - val_loss: 0.7065 - val_accuracy: 0.7222
# Epoch 117/300
#
# Epoch 00117: val_loss improved from 0.69250 to 0.68069, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.5644 - accuracy: 0.8681 - val_loss: 0.6807 - val_accuracy: 0.7500
# Epoch 118/300
#
# Epoch 00118: val_loss improved from 0.68069 to 0.68056, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.6046 - accuracy: 0.8472 - val_loss: 0.6806 - val_accuracy: 0.7361
# Epoch 119/300
#
# Epoch 00119: val_loss did not improve from 0.68056
# 9/9 - 0s - loss: 0.6002 - accuracy: 0.8333 - val_loss: 0.7055 - val_accuracy: 0.7222
# Epoch 120/300
#
# Epoch 00120: val_loss did not improve from 0.68056
# 9/9 - 0s - loss: 0.5919 - accuracy: 0.8403 - val_loss: 0.7008 - val_accuracy: 0.7083
# Epoch 121/300
#
# Epoch 00121: val_loss did not improve from 0.68056
# 9/9 - 0s - loss: 0.6035 - accuracy: 0.8333 - val_loss: 0.6845 - val_accuracy: 0.7361
# Epoch 122/300
#
# Epoch 00122: val_loss did not improve from 0.68056
# 9/9 - 0s - loss: 0.5512 - accuracy: 0.8958 - val_loss: 0.6921 - val_accuracy: 0.7083
# Epoch 123/300
#
# Epoch 00123: val_loss did not improve from 0.68056
# 9/9 - 0s - loss: 0.5945 - accuracy: 0.8194 - val_loss: 0.7189 - val_accuracy: 0.7222
# Epoch 124/300
#
# Epoch 00124: val_loss did not improve from 0.68056
# 9/9 - 0s - loss: 0.5731 - accuracy: 0.8472 - val_loss: 0.7010 - val_accuracy: 0.7222
# Epoch 125/300
#
# Epoch 00125: val_loss improved from 0.68056 to 0.68021, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.5619 - accuracy: 0.8611 - val_loss: 0.6802 - val_accuracy: 0.7222
# Epoch 126/300
#
# Epoch 00126: val_loss improved from 0.68021 to 0.67489, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.5799 - accuracy: 0.8611 - val_loss: 0.6749 - val_accuracy: 0.7083
# Epoch 127/300
#
# Epoch 00127: val_loss did not improve from 0.67489
# 9/9 - 0s - loss: 0.5590 - accuracy: 0.8542 - val_loss: 0.7081 - val_accuracy: 0.7222
# Epoch 128/300
#
# Epoch 00128: val_loss did not improve from 0.67489
# 9/9 - 0s - loss: 0.5564 - accuracy: 0.8403 - val_loss: 0.7186 - val_accuracy: 0.7500
# Epoch 129/300
#
# Epoch 00129: val_loss did not improve from 0.67489
# 9/9 - 0s - loss: 0.5551 - accuracy: 0.8611 - val_loss: 0.6872 - val_accuracy: 0.7778
# Epoch 130/300
#
# Epoch 00130: val_loss did not improve from 0.67489
# 9/9 - 0s - loss: 0.5588 - accuracy: 0.8542 - val_loss: 0.6754 - val_accuracy: 0.7222
# Epoch 131/300
#
# Epoch 00131: val_loss did not improve from 0.67489
# 9/9 - 0s - loss: 0.5728 - accuracy: 0.8611 - val_loss: 0.6838 - val_accuracy: 0.7083
# Epoch 132/300
#
# Epoch 00132: val_loss improved from 0.67489 to 0.67105, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.5565 - accuracy: 0.8819 - val_loss: 0.6711 - val_accuracy: 0.7222
# Epoch 133/300
#
# Epoch 00133: val_loss did not improve from 0.67105
# 9/9 - 0s - loss: 0.5533 - accuracy: 0.8681 - val_loss: 0.6800 - val_accuracy: 0.7500
# Epoch 134/300
#
# Epoch 00134: val_loss did not improve from 0.67105
# 9/9 - 0s - loss: 0.5900 - accuracy: 0.8333 - val_loss: 0.6804 - val_accuracy: 0.7222
# Epoch 135/300
#
# Epoch 00135: val_loss did not improve from 0.67105
# 9/9 - 0s - loss: 0.5356 - accuracy: 0.8750 - val_loss: 0.6857 - val_accuracy: 0.7222
# Epoch 136/300
#
# Epoch 00136: val_loss did not improve from 0.67105
# 9/9 - 0s - loss: 0.5591 - accuracy: 0.8611 - val_loss: 0.6867 - val_accuracy: 0.7361
# Epoch 137/300
#
# Epoch 00137: val_loss did not improve from 0.67105
# 9/9 - 0s - loss: 0.5589 - accuracy: 0.8750 - val_loss: 0.6906 - val_accuracy: 0.7222
# Epoch 138/300
#
# Epoch 00138: val_loss did not improve from 0.67105
# 9/9 - 0s - loss: 0.5410 - accuracy: 0.8403 - val_loss: 0.7041 - val_accuracy: 0.7083
# Epoch 139/300
#
# Epoch 00139: val_loss did not improve from 0.67105
# 9/9 - 0s - loss: 0.5407 - accuracy: 0.8750 - val_loss: 0.6952 - val_accuracy: 0.7222
# Epoch 140/300
#
# Epoch 00140: val_loss did not improve from 0.67105
# 9/9 - 0s - loss: 0.5340 - accuracy: 0.8681 - val_loss: 0.6729 - val_accuracy: 0.7083
# Epoch 141/300
#
# Epoch 00141: val_loss did not improve from 0.67105
# 9/9 - 0s - loss: 0.5782 - accuracy: 0.8056 - val_loss: 0.6811 - val_accuracy: 0.7222
# Epoch 142/300
#
# Epoch 00142: val_loss did not improve from 0.67105
# 9/9 - 0s - loss: 0.5260 - accuracy: 0.8681 - val_loss: 0.6893 - val_accuracy: 0.7222
# Epoch 143/300
#
# Epoch 00143: val_loss did not improve from 0.67105
# 9/9 - 0s - loss: 0.5351 - accuracy: 0.8681 - val_loss: 0.6775 - val_accuracy: 0.7222
# Epoch 144/300
#
# Epoch 00144: val_loss did not improve from 0.67105
# 9/9 - 0s - loss: 0.5598 - accuracy: 0.8403 - val_loss: 0.7148 - val_accuracy: 0.7639
# Epoch 145/300
#
# Epoch 00145: val_loss improved from 0.67105 to 0.66916, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.5452 - accuracy: 0.8958 - val_loss: 0.6692 - val_accuracy: 0.7639
# Epoch 146/300
#
# Epoch 00146: val_loss did not improve from 0.66916
# 9/9 - 0s - loss: 0.5568 - accuracy: 0.8681 - val_loss: 0.6938 - val_accuracy: 0.7778
# Epoch 147/300
#
# Epoch 00147: val_loss did not improve from 0.66916
# 9/9 - 0s - loss: 0.5259 - accuracy: 0.8750 - val_loss: 0.6977 - val_accuracy: 0.7917
# Epoch 148/300
#
# Epoch 00148: val_loss improved from 0.66916 to 0.64867, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.5391 - accuracy: 0.8681 - val_loss: 0.6487 - val_accuracy: 0.7361
# Epoch 149/300
#
# Epoch 00149: val_loss did not improve from 0.64867
# 9/9 - 0s - loss: 0.5348 - accuracy: 0.8819 - val_loss: 0.6759 - val_accuracy: 0.7500
# Epoch 150/300
#
# Epoch 00150: val_loss did not improve from 0.64867
# 9/9 - 0s - loss: 0.5344 - accuracy: 0.8750 - val_loss: 0.6624 - val_accuracy: 0.7361
# Epoch 151/300
#
# Epoch 00151: val_loss did not improve from 0.64867
# 9/9 - 0s - loss: 0.5272 - accuracy: 0.8542 - val_loss: 0.6567 - val_accuracy: 0.7361
# Epoch 152/300
#
# Epoch 00152: val_loss improved from 0.64867 to 0.64776, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.5231 - accuracy: 0.8611 - val_loss: 0.6478 - val_accuracy: 0.7361
# Epoch 153/300
#
# Epoch 00153: val_loss did not improve from 0.64776
# 9/9 - 0s - loss: 0.5257 - accuracy: 0.8472 - val_loss: 0.6705 - val_accuracy: 0.7778
# Epoch 154/300
#
# Epoch 00154: val_loss did not improve from 0.64776
# 9/9 - 0s - loss: 0.5471 - accuracy: 0.8681 - val_loss: 0.6590 - val_accuracy: 0.7639
# Epoch 155/300
#
# Epoch 00155: val_loss did not improve from 0.64776
# 9/9 - 0s - loss: 0.5094 - accuracy: 0.9097 - val_loss: 0.6575 - val_accuracy: 0.7361
# Epoch 156/300
#
# Epoch 00156: val_loss did not improve from 0.64776
# 9/9 - 0s - loss: 0.5039 - accuracy: 0.8819 - val_loss: 0.6743 - val_accuracy: 0.7361
# Epoch 157/300
#
# Epoch 00157: val_loss did not improve from 0.64776
# 9/9 - 0s - loss: 0.5314 - accuracy: 0.8264 - val_loss: 0.6813 - val_accuracy: 0.7361
# Epoch 158/300
#
# Epoch 00158: val_loss did not improve from 0.64776
# 9/9 - 0s - loss: 0.5052 - accuracy: 0.9097 - val_loss: 0.6814 - val_accuracy: 0.7222
# Epoch 159/300
#
# Epoch 00159: val_loss did not improve from 0.64776
# 9/9 - 0s - loss: 0.5303 - accuracy: 0.8958 - val_loss: 0.6688 - val_accuracy: 0.7361
# Epoch 160/300
#
# Epoch 00160: val_loss did not improve from 0.64776
# 9/9 - 0s - loss: 0.5351 - accuracy: 0.8681 - val_loss: 0.6771 - val_accuracy: 0.7222
# Epoch 161/300
#
# Epoch 00161: val_loss did not improve from 0.64776
# 9/9 - 0s - loss: 0.5067 - accuracy: 0.8819 - val_loss: 0.6672 - val_accuracy: 0.7222
# Epoch 162/300
#
# Epoch 00162: val_loss did not improve from 0.64776
# 9/9 - 0s - loss: 0.5198 - accuracy: 0.8750 - val_loss: 0.6763 - val_accuracy: 0.7500
# Epoch 163/300
#
# Epoch 00163: val_loss did not improve from 0.64776
# 9/9 - 0s - loss: 0.5168 - accuracy: 0.8750 - val_loss: 0.6538 - val_accuracy: 0.7500
# Epoch 164/300
#
# Epoch 00164: val_loss improved from 0.64776 to 0.63174, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.5100 - accuracy: 0.8681 - val_loss: 0.6317 - val_accuracy: 0.7500
# Epoch 165/300
#
# Epoch 00165: val_loss did not improve from 0.63174
# 9/9 - 0s - loss: 0.5609 - accuracy: 0.8125 - val_loss: 0.6661 - val_accuracy: 0.7361
# Epoch 166/300
#
# Epoch 00166: val_loss did not improve from 0.63174
# 9/9 - 0s - loss: 0.5089 - accuracy: 0.8681 - val_loss: 0.7001 - val_accuracy: 0.7222
# Epoch 167/300
#
# Epoch 00167: val_loss did not improve from 0.63174
# 9/9 - 0s - loss: 0.5043 - accuracy: 0.8403 - val_loss: 0.6487 - val_accuracy: 0.7361
# Epoch 168/300
#
# Epoch 00168: val_loss did not improve from 0.63174
# 9/9 - 0s - loss: 0.4798 - accuracy: 0.9097 - val_loss: 0.6421 - val_accuracy: 0.7500
# Epoch 169/300
#
# Epoch 00169: val_loss did not improve from 0.63174
# 9/9 - 0s - loss: 0.5086 - accuracy: 0.8542 - val_loss: 0.6656 - val_accuracy: 0.7361
# Epoch 170/300
#
# Epoch 00170: val_loss did not improve from 0.63174
# 9/9 - 0s - loss: 0.5208 - accuracy: 0.8542 - val_loss: 0.6750 - val_accuracy: 0.7222
# Epoch 171/300
#
# Epoch 00171: val_loss did not improve from 0.63174
# 9/9 - 0s - loss: 0.4751 - accuracy: 0.9028 - val_loss: 0.6519 - val_accuracy: 0.7361
# Epoch 172/300
#
# Epoch 00172: val_loss did not improve from 0.63174
# 9/9 - 0s - loss: 0.5114 - accuracy: 0.8750 - val_loss: 0.6367 - val_accuracy: 0.7500
# Epoch 173/300
#
# Epoch 00173: val_loss did not improve from 0.63174
# 9/9 - 0s - loss: 0.4979 - accuracy: 0.8889 - val_loss: 0.6743 - val_accuracy: 0.7083
# Epoch 174/300
#
# Epoch 00174: val_loss did not improve from 0.63174
# 9/9 - 0s - loss: 0.4707 - accuracy: 0.8958 - val_loss: 0.6595 - val_accuracy: 0.7500
# Epoch 175/300
#
# Epoch 00175: val_loss did not improve from 0.63174
# 9/9 - 0s - loss: 0.4848 - accuracy: 0.9167 - val_loss: 0.6421 - val_accuracy: 0.6944
# Epoch 176/300
#
# Epoch 00176: val_loss did not improve from 0.63174
# 9/9 - 0s - loss: 0.5008 - accuracy: 0.9167 - val_loss: 0.6615 - val_accuracy: 0.7083
# Epoch 177/300
#
# Epoch 00177: val_loss did not improve from 0.63174
# 9/9 - 0s - loss: 0.5112 - accuracy: 0.8542 - val_loss: 0.6513 - val_accuracy: 0.7500
# Epoch 178/300
#
# Epoch 00178: val_loss did not improve from 0.63174
# 9/9 - 0s - loss: 0.5180 - accuracy: 0.8889 - val_loss: 0.6671 - val_accuracy: 0.7361
# Epoch 179/300
#
# Epoch 00179: val_loss improved from 0.63174 to 0.63072, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.5079 - accuracy: 0.8611 - val_loss: 0.6307 - val_accuracy: 0.7361
# Epoch 180/300
#
# Epoch 00180: val_loss did not improve from 0.63072
# 9/9 - 0s - loss: 0.4727 - accuracy: 0.9028 - val_loss: 0.6723 - val_accuracy: 0.7083
# Epoch 181/300
#
# Epoch 00181: val_loss did not improve from 0.63072
# 9/9 - 0s - loss: 0.4895 - accuracy: 0.8403 - val_loss: 0.6859 - val_accuracy: 0.7083
# Epoch 182/300
#
# Epoch 00182: val_loss did not improve from 0.63072
# 9/9 - 0s - loss: 0.4965 - accuracy: 0.8819 - val_loss: 0.6457 - val_accuracy: 0.7222
# Epoch 183/300
#
# Epoch 00183: val_loss did not improve from 0.63072
# 9/9 - 0s - loss: 0.4782 - accuracy: 0.8889 - val_loss: 0.6437 - val_accuracy: 0.7083
# Epoch 184/300
#
# Epoch 00184: val_loss did not improve from 0.63072
# 9/9 - 0s - loss: 0.4512 - accuracy: 0.9167 - val_loss: 0.6708 - val_accuracy: 0.7500
# Epoch 185/300
#
# Epoch 00185: val_loss improved from 0.63072 to 0.63051, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.5084 - accuracy: 0.9028 - val_loss: 0.6305 - val_accuracy: 0.7500
# Epoch 186/300
#
# Epoch 00186: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4959 - accuracy: 0.8750 - val_loss: 0.6336 - val_accuracy: 0.7500
# Epoch 187/300
#
# Epoch 00187: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4504 - accuracy: 0.9167 - val_loss: 0.6422 - val_accuracy: 0.7222
# Epoch 188/300
#
# Epoch 00188: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4443 - accuracy: 0.9375 - val_loss: 0.6476 - val_accuracy: 0.7361
# Epoch 189/300
#
# Epoch 00189: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4798 - accuracy: 0.8750 - val_loss: 0.6695 - val_accuracy: 0.7639
# Epoch 190/300
#
# Epoch 00190: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4793 - accuracy: 0.9028 - val_loss: 0.6513 - val_accuracy: 0.7361
# Epoch 191/300
#
# Epoch 00191: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4753 - accuracy: 0.8611 - val_loss: 0.6765 - val_accuracy: 0.7083
# Epoch 192/300
#
# Epoch 00192: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4818 - accuracy: 0.8750 - val_loss: 0.6562 - val_accuracy: 0.7222
# Epoch 193/300
#
# Epoch 00193: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4738 - accuracy: 0.8681 - val_loss: 0.6485 - val_accuracy: 0.7361
# Epoch 194/300
#
# Epoch 00194: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4786 - accuracy: 0.8889 - val_loss: 0.6647 - val_accuracy: 0.7361
# Epoch 195/300
#
# Epoch 00195: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4759 - accuracy: 0.8889 - val_loss: 0.6460 - val_accuracy: 0.7361
# Epoch 196/300
#
# Epoch 00196: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4806 - accuracy: 0.9097 - val_loss: 0.6599 - val_accuracy: 0.7500
# Epoch 197/300
#
# Epoch 00197: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4515 - accuracy: 0.9167 - val_loss: 0.6716 - val_accuracy: 0.7500
# Epoch 198/300
#
# Epoch 00198: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4590 - accuracy: 0.9167 - val_loss: 0.6732 - val_accuracy: 0.7361
# Epoch 199/300
#
# Epoch 00199: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4709 - accuracy: 0.9097 - val_loss: 0.6452 - val_accuracy: 0.7500
# Epoch 200/300
#
# Epoch 00200: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4308 - accuracy: 0.9444 - val_loss: 0.6658 - val_accuracy: 0.7222
# Epoch 201/300
#
# Epoch 00201: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4827 - accuracy: 0.8958 - val_loss: 0.6819 - val_accuracy: 0.7361
# Epoch 202/300
#
# Epoch 00202: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4583 - accuracy: 0.9375 - val_loss: 0.6615 - val_accuracy: 0.7361
# Epoch 203/300
#
# Epoch 00203: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4478 - accuracy: 0.9236 - val_loss: 0.6687 - val_accuracy: 0.7361
# Epoch 204/300
#
# Epoch 00204: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4948 - accuracy: 0.8611 - val_loss: 0.7119 - val_accuracy: 0.7361
# Epoch 205/300
#
# Epoch 00205: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.3878 - accuracy: 0.9514 - val_loss: 0.6938 - val_accuracy: 0.7361
# Epoch 206/300
#
# Epoch 00206: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4306 - accuracy: 0.9236 - val_loss: 0.6752 - val_accuracy: 0.7500
# Epoch 207/300
#
# Epoch 00207: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4772 - accuracy: 0.9097 - val_loss: 0.6760 - val_accuracy: 0.7500
# Epoch 208/300
#
# Epoch 00208: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4305 - accuracy: 0.9514 - val_loss: 0.6492 - val_accuracy: 0.7361
# Epoch 209/300
#
# Epoch 00209: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4448 - accuracy: 0.9097 - val_loss: 0.6715 - val_accuracy: 0.7500
# Epoch 210/300
#
# Epoch 00210: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4304 - accuracy: 0.9306 - val_loss: 0.6622 - val_accuracy: 0.7222
# Epoch 211/300
#
# Epoch 00211: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4467 - accuracy: 0.8889 - val_loss: 0.6479 - val_accuracy: 0.7222
# Epoch 212/300
#
# Epoch 00212: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4576 - accuracy: 0.8958 - val_loss: 0.6456 - val_accuracy: 0.7083
# Epoch 213/300
#
# Epoch 00213: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4328 - accuracy: 0.9028 - val_loss: 0.6391 - val_accuracy: 0.7361
# Epoch 214/300
#
# Epoch 00214: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4204 - accuracy: 0.9306 - val_loss: 0.6590 - val_accuracy: 0.7222
# Epoch 215/300
#
# Epoch 00215: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4486 - accuracy: 0.8958 - val_loss: 0.6501 - val_accuracy: 0.7083
# Epoch 216/300
#
# Epoch 00216: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4698 - accuracy: 0.8750 - val_loss: 0.6567 - val_accuracy: 0.7361
# Epoch 217/300
#
# Epoch 00217: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4533 - accuracy: 0.9028 - val_loss: 0.6460 - val_accuracy: 0.7222
# Epoch 218/300
#
# Epoch 00218: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4544 - accuracy: 0.9097 - val_loss: 0.6436 - val_accuracy: 0.7222
# Epoch 219/300
#
# Epoch 00219: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4562 - accuracy: 0.8958 - val_loss: 0.6451 - val_accuracy: 0.7222
# Epoch 220/300
#
# Epoch 00220: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4827 - accuracy: 0.8819 - val_loss: 0.6500 - val_accuracy: 0.7083
# Epoch 221/300
#
# Epoch 00221: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4380 - accuracy: 0.9167 - val_loss: 0.6377 - val_accuracy: 0.7083
# Epoch 222/300
#
# Epoch 00222: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4307 - accuracy: 0.9167 - val_loss: 0.6458 - val_accuracy: 0.7222
# Epoch 223/300
#
# Epoch 00223: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4157 - accuracy: 0.9444 - val_loss: 0.6409 - val_accuracy: 0.7500
# Epoch 224/300
#
# Epoch 00224: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4438 - accuracy: 0.9167 - val_loss: 0.6680 - val_accuracy: 0.7222
# Epoch 225/300
#
# Epoch 00225: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4366 - accuracy: 0.9236 - val_loss: 0.6647 - val_accuracy: 0.7083
# Epoch 226/300
#
# Epoch 00226: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4445 - accuracy: 0.8750 - val_loss: 0.6475 - val_accuracy: 0.7222
# Epoch 227/300
#
# Epoch 00227: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4253 - accuracy: 0.9167 - val_loss: 0.6311 - val_accuracy: 0.7083
# Epoch 228/300
#
# Epoch 00228: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4770 - accuracy: 0.8750 - val_loss: 0.6556 - val_accuracy: 0.7500
# Epoch 229/300
#
# Epoch 00229: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4069 - accuracy: 0.9236 - val_loss: 0.6627 - val_accuracy: 0.7222
# Epoch 230/300
#
# Epoch 00230: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4262 - accuracy: 0.9236 - val_loss: 0.6463 - val_accuracy: 0.7222
# Epoch 231/300
#
# Epoch 00231: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4203 - accuracy: 0.9444 - val_loss: 0.6307 - val_accuracy: 0.7222
# Epoch 232/300
#
# Epoch 00232: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4526 - accuracy: 0.8750 - val_loss: 0.6367 - val_accuracy: 0.7361
# Epoch 233/300
#
# Epoch 00233: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4535 - accuracy: 0.8750 - val_loss: 0.6467 - val_accuracy: 0.7361
# Epoch 234/300
#
# Epoch 00234: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4502 - accuracy: 0.8750 - val_loss: 0.6497 - val_accuracy: 0.7222
# Epoch 235/300
#
# Epoch 00235: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4117 - accuracy: 0.9167 - val_loss: 0.6527 - val_accuracy: 0.7083
# Epoch 236/300
#
# Epoch 00236: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4252 - accuracy: 0.9167 - val_loss: 0.6563 - val_accuracy: 0.7222
# Epoch 237/300
#
# Epoch 00237: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4444 - accuracy: 0.8889 - val_loss: 0.6442 - val_accuracy: 0.7639
# Epoch 238/300
#
# Epoch 00238: val_loss did not improve from 0.63051
# 9/9 - 0s - loss: 0.4211 - accuracy: 0.9097 - val_loss: 0.6552 - val_accuracy: 0.7222
# Epoch 239/300
#
# Epoch 00239: val_loss improved from 0.63051 to 0.61999, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.4168 - accuracy: 0.9375 - val_loss: 0.6200 - val_accuracy: 0.7361
# Epoch 240/300
#
# Epoch 00240: val_loss did not improve from 0.61999
# 9/9 - 0s - loss: 0.4197 - accuracy: 0.8889 - val_loss: 0.6376 - val_accuracy: 0.7361
# Epoch 241/300
#
# Epoch 00241: val_loss did not improve from 0.61999
# 9/9 - 0s - loss: 0.4270 - accuracy: 0.9167 - val_loss: 0.6353 - val_accuracy: 0.7222
# Epoch 242/300
#
# Epoch 00242: val_loss did not improve from 0.61999
# 9/9 - 0s - loss: 0.4440 - accuracy: 0.9028 - val_loss: 0.6456 - val_accuracy: 0.7361
# Epoch 243/300
#
# Epoch 00243: val_loss did not improve from 0.61999
# 9/9 - 0s - loss: 0.4365 - accuracy: 0.8958 - val_loss: 0.6438 - val_accuracy: 0.7222
# Epoch 244/300
#
# Epoch 00244: val_loss improved from 0.61999 to 0.61813, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.4020 - accuracy: 0.9167 - val_loss: 0.6181 - val_accuracy: 0.7361
# Epoch 245/300
#
# Epoch 00245: val_loss did not improve from 0.61813
# 9/9 - 0s - loss: 0.4032 - accuracy: 0.9236 - val_loss: 0.6295 - val_accuracy: 0.7500
# Epoch 246/300
#
# Epoch 00246: val_loss did not improve from 0.61813
# 9/9 - 0s - loss: 0.4035 - accuracy: 0.8958 - val_loss: 0.6357 - val_accuracy: 0.7500
# Epoch 247/300
#
# Epoch 00247: val_loss did not improve from 0.61813
# 9/9 - 0s - loss: 0.4223 - accuracy: 0.9097 - val_loss: 0.6311 - val_accuracy: 0.7500
# Epoch 248/300
#
# Epoch 00248: val_loss did not improve from 0.61813
# 9/9 - 0s - loss: 0.4183 - accuracy: 0.9028 - val_loss: 0.6567 - val_accuracy: 0.7361
# Epoch 249/300
#
# Epoch 00249: val_loss did not improve from 0.61813
# 9/9 - 0s - loss: 0.4455 - accuracy: 0.8958 - val_loss: 0.6225 - val_accuracy: 0.7361
# Epoch 250/300
#
# Epoch 00250: val_loss did not improve from 0.61813
# 9/9 - 0s - loss: 0.4289 - accuracy: 0.9236 - val_loss: 0.6462 - val_accuracy: 0.7083
# Epoch 251/300
#
# Epoch 00251: val_loss did not improve from 0.61813
# 9/9 - 0s - loss: 0.4276 - accuracy: 0.9097 - val_loss: 0.6506 - val_accuracy: 0.7083
# Epoch 252/300
#
# Epoch 00252: val_loss did not improve from 0.61813
# 9/9 - 0s - loss: 0.4006 - accuracy: 0.9028 - val_loss: 0.6482 - val_accuracy: 0.7361
# Epoch 253/300
#
# Epoch 00253: val_loss did not improve from 0.61813
# 9/9 - 0s - loss: 0.4113 - accuracy: 0.9306 - val_loss: 0.6409 - val_accuracy: 0.7639
# Epoch 254/300
#
# Epoch 00254: val_loss did not improve from 0.61813
# 9/9 - 0s - loss: 0.3960 - accuracy: 0.9306 - val_loss: 0.6410 - val_accuracy: 0.7361
# Epoch 255/300
#
# Epoch 00255: val_loss did not improve from 0.61813
# 9/9 - 0s - loss: 0.4206 - accuracy: 0.9236 - val_loss: 0.6499 - val_accuracy: 0.7500
# Epoch 256/300
#
# Epoch 00256: val_loss did not improve from 0.61813
# 9/9 - 0s - loss: 0.4016 - accuracy: 0.9236 - val_loss: 0.6501 - val_accuracy: 0.7361
# Epoch 257/300
#
# Epoch 00257: val_loss did not improve from 0.61813
# 9/9 - 0s - loss: 0.3967 - accuracy: 0.9236 - val_loss: 0.6600 - val_accuracy: 0.7222
# Epoch 258/300
#
# Epoch 00258: val_loss did not improve from 0.61813
# 9/9 - 0s - loss: 0.4265 - accuracy: 0.8403 - val_loss: 0.6649 - val_accuracy: 0.7361
# Epoch 259/300
#
# Epoch 00259: val_loss did not improve from 0.61813
# 9/9 - 0s - loss: 0.3993 - accuracy: 0.9097 - val_loss: 0.6370 - val_accuracy: 0.7500
# Epoch 260/300
#
# Epoch 00260: val_loss did not improve from 0.61813
# 9/9 - 0s - loss: 0.4056 - accuracy: 0.8958 - val_loss: 0.6295 - val_accuracy: 0.7222
# Epoch 261/300
#
# Epoch 00261: val_loss did not improve from 0.61813
# 9/9 - 0s - loss: 0.3793 - accuracy: 0.9375 - val_loss: 0.6779 - val_accuracy: 0.7083
# Epoch 262/300
#
# Epoch 00262: val_loss did not improve from 0.61813
# 9/9 - 0s - loss: 0.4149 - accuracy: 0.9028 - val_loss: 0.6352 - val_accuracy: 0.7222
# Epoch 263/300
#
# Epoch 00263: val_loss did not improve from 0.61813
# 9/9 - 0s - loss: 0.3831 - accuracy: 0.9444 - val_loss: 0.6271 - val_accuracy: 0.7361
# Epoch 264/300
#
# Epoch 00264: val_loss did not improve from 0.61813
# 9/9 - 0s - loss: 0.3738 - accuracy: 0.9236 - val_loss: 0.6377 - val_accuracy: 0.7361
# Epoch 265/300
#
# Epoch 00265: val_loss did not improve from 0.61813
# 9/9 - 0s - loss: 0.3883 - accuracy: 0.9167 - val_loss: 0.6810 - val_accuracy: 0.6944
# Epoch 266/300
#
# Epoch 00266: val_loss did not improve from 0.61813
# 9/9 - 0s - loss: 0.4187 - accuracy: 0.9306 - val_loss: 0.6434 - val_accuracy: 0.7500
# Epoch 267/300
#
# Epoch 00267: val_loss improved from 0.61813 to 0.61694, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.3763 - accuracy: 0.9306 - val_loss: 0.6169 - val_accuracy: 0.7361
# Epoch 268/300
#
# Epoch 00268: val_loss did not improve from 0.61694
# 9/9 - 0s - loss: 0.4019 - accuracy: 0.8958 - val_loss: 0.6307 - val_accuracy: 0.7361
# Epoch 269/300
#
# Epoch 00269: val_loss did not improve from 0.61694
# 9/9 - 0s - loss: 0.3806 - accuracy: 0.9236 - val_loss: 0.6547 - val_accuracy: 0.7083
# Epoch 270/300
#
# Epoch 00270: val_loss improved from 0.61694 to 0.60122, saving model to /tmp\checkpoint.h5
# 9/9 - 0s - loss: 0.4059 - accuracy: 0.9028 - val_loss: 0.6012 - val_accuracy: 0.7361
# Epoch 271/300
#
# Epoch 00271: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.3997 - accuracy: 0.9097 - val_loss: 0.6218 - val_accuracy: 0.7361
# Epoch 272/300
#
# Epoch 00272: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.4006 - accuracy: 0.9167 - val_loss: 0.6486 - val_accuracy: 0.7222
# Epoch 273/300
#
# Epoch 00273: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.3781 - accuracy: 0.9375 - val_loss: 0.6190 - val_accuracy: 0.7083
# Epoch 274/300
#
# Epoch 00274: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.3737 - accuracy: 0.9306 - val_loss: 0.6250 - val_accuracy: 0.7222
# Epoch 275/300
#
# Epoch 00275: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.4099 - accuracy: 0.9097 - val_loss: 0.6305 - val_accuracy: 0.7639
# Epoch 276/300
#
# Epoch 00276: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.4052 - accuracy: 0.8958 - val_loss: 0.6578 - val_accuracy: 0.7361
# Epoch 277/300
#
# Epoch 00277: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.3804 - accuracy: 0.9514 - val_loss: 0.6512 - val_accuracy: 0.7083
# Epoch 278/300
#
# Epoch 00278: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.3963 - accuracy: 0.9028 - val_loss: 0.6393 - val_accuracy: 0.7361
# Epoch 279/300
#
# Epoch 00279: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.3666 - accuracy: 0.9306 - val_loss: 0.6250 - val_accuracy: 0.7222
# Epoch 280/300
#
# Epoch 00280: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.4038 - accuracy: 0.9236 - val_loss: 0.6493 - val_accuracy: 0.7500
# Epoch 281/300
#
# Epoch 00281: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.4052 - accuracy: 0.9236 - val_loss: 0.6247 - val_accuracy: 0.7222
# Epoch 282/300
#
# Epoch 00282: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.3664 - accuracy: 0.9306 - val_loss: 0.6268 - val_accuracy: 0.7639
# Epoch 283/300
#
# Epoch 00283: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.3968 - accuracy: 0.8958 - val_loss: 0.6389 - val_accuracy: 0.7639
# Epoch 284/300
#
# Epoch 00284: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.3999 - accuracy: 0.8750 - val_loss: 0.6355 - val_accuracy: 0.7361
# Epoch 285/300
#
# Epoch 00285: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.3802 - accuracy: 0.9306 - val_loss: 0.6388 - val_accuracy: 0.7222
# Epoch 286/300
#
# Epoch 00286: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.3997 - accuracy: 0.9444 - val_loss: 0.6273 - val_accuracy: 0.7361
# Epoch 287/300
#
# Epoch 00287: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.3735 - accuracy: 0.9097 - val_loss: 0.6708 - val_accuracy: 0.6667
# Epoch 288/300
#
# Epoch 00288: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.4168 - accuracy: 0.8681 - val_loss: 0.6547 - val_accuracy: 0.7361
# Epoch 289/300
#
# Epoch 00289: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.4387 - accuracy: 0.8889 - val_loss: 0.6374 - val_accuracy: 0.7500
# Epoch 290/300
#
# Epoch 00290: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.3832 - accuracy: 0.9167 - val_loss: 0.6574 - val_accuracy: 0.7361
# Epoch 291/300
#
# Epoch 00291: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.3606 - accuracy: 0.9236 - val_loss: 0.6511 - val_accuracy: 0.6944
# Epoch 292/300
#
# Epoch 00292: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.3921 - accuracy: 0.9236 - val_loss: 0.6126 - val_accuracy: 0.7361
# Epoch 293/300
#
# Epoch 00293: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.3706 - accuracy: 0.8958 - val_loss: 0.6479 - val_accuracy: 0.6944
# Epoch 294/300
#
# Epoch 00294: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.4143 - accuracy: 0.8819 - val_loss: 0.6500 - val_accuracy: 0.7083
# Epoch 295/300
#
# Epoch 00295: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.4117 - accuracy: 0.9097 - val_loss: 0.6386 - val_accuracy: 0.7361
# Epoch 296/300
#
# Epoch 00296: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.3504 - accuracy: 0.9375 - val_loss: 0.6264 - val_accuracy: 0.7222
# Epoch 297/300
#
# Epoch 00297: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.3746 - accuracy: 0.9236 - val_loss: 0.6598 - val_accuracy: 0.7083
# Epoch 298/300
#
# Epoch 00298: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.3615 - accuracy: 0.9097 - val_loss: 0.6757 - val_accuracy: 0.7083
# Epoch 299/300
#
# Epoch 00299: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.3977 - accuracy: 0.8889 - val_loss: 0.6491 - val_accuracy: 0.7361
# Epoch 300/300
#
# Epoch 00300: val_loss did not improve from 0.60122
# 9/9 - 0s - loss: 0.3992 - accuracy: 0.8889 - val_loss: 0.6424 - val_accuracy: 0.7222
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-07b3ad2a983f> in <module>
#      55
#      56 # load optimal weights
# ---> 57 model.load_weights('/tmp/checkpoint.h5')
#      58
#      59 ###############################################################################
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in load_weights(self, filepath, by_name, skip_mismatch, options)
#    2202           'first, then load the weights.')
#    2203     self._assert_weights_created()
# -> 2204     with h5py.File(filepath, 'r') as f:
#    2205       if 'layer_names' not in f.attrs and 'model_weights' in f:
#    2206         f = f['model_weights']
#
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\_hl\files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     404             with phil:
#     405                 fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0, **kwds)
# --> 406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
#     408                                swmr=swmr)
#
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\_hl\files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     171         if swmr and swmr_support:
#     172             flags |= h5f.ACC_SWMR_READ
# --> 173         fid = h5f.open(name, flags, fapl=fapl)
#     174     elif mode == 'r+':
#     175         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py\h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = '/tmp/checkpoint.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
